# %%
import pandas as pd
import numpy as np

# %%
from sklearn import linear_model as lm, metrics
from importlib import reload
import linear_model
import metrics
import resample
import stats

# %%
reload(linear_model)
reload(metrics)
reload(resample)
reload(stats)
# Out:
# <module 'stats' from '/home/igor/Dropbox/UFC/7°Semestre/Aprendizado de Máquina/atividades/Lista 3/stats.py'>

# %% [markdown]
# ### Crie um Jupyter Notebook e use as bibliotecas criadas na Questão 1 para fazer o que se pede:
#
# a) Represente os dados a seguir:
# ![image.png](attachment:image.png)

# %%
df = pd.DataFrame({'x':[1400,1600,1700,1875,1100,1550,2350,2450,1425,1700], 'y':[245000,312000,279000,308000,199000,219000,405000,324000,319000,255000]})

# %%
df
# Out:
#       x       y
# 0  1400  245000
# 1  1600  312000
# 2  1700  279000
# 3  1875  308000
# 4  1100  199000
# 5  1550  219000
# 6  2350  405000
# 7  2450  324000
# 8  1425  319000
# 9  1700  255000

# %% [markdown]
# b) Calcule média, desvio padrão e variância de X.

# %%
print("A média é: {}".format(stats.mean(df['x'])))
# Out:
# A média é: 1715.0

# %%
print("O desvio padrão é: {}".format(stats.stdev(df['x'])))
# Out:
# O desvio padrão é: 396.42149285829595

# %%
print("A variância é de: {}".format(stats.var(df['x'])))
# Out:
# A variância é de: 157150.0

# %% [markdown]
# c) Divida os dados X, y para 70% de treino e 30% de teste. O resultado deve estar nas variáveis: X_train, y_train, X_test, y_test.
#
# - Dicas:
#     - X_train = X[idx_train], onde idx_train é um array com os índices dos dados de treino.
#     - y_train = y[idx_train]
#     - X_test = X[idx_test]
#     - y_test = y[idx_test]

# %%
train, test = resample.split_train_test(10,0.7,2)

# %%
train_label, test_label = resample.split_train_test(10,0.7,3)

# %% [markdown]
# e) Treine os modelos com os dados de treino (X_train, y_train).

# %%
my_model = linear_model.SimpleLinearRegression()

# %%
sk_model = lm.LinearRegression()

# %% [markdown]
# e) Treine os modelos com os dados de treino (X_train, y_train).

# %%
X_ = np.array(train)
y_ = np.array(train_label)
my_model.fit(X_,y_)

# %%
X_ = [[i] for i in train]
y_ = [[i] for i in train_label]
sk_model.fit(X_,y_)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# f) Faça as predições para os modelos usando os dados de teste (X_test).

# %%
y_pred = []
for i in test: 
    y_pred.append(my_model.predict(i))

# %%
print(train, test)
print(train_label, test_label)
# Out:
# [4, 1, 5, 0, 7, 2, 3] [6, 9, 8]
# [5, 4, 1, 2, 9, 6, 7] [0, 3, 8]

# %%
y_pred
# Out:
# [0.0224, 0.03311428571428572, 0.029542857142857145]

# %%
y_pred = []
for x in test:
    y_pred.append(sk_model.predict(x))

# %%
y_pred
# Out:
# [array([[6.3442623]]), array([[7.9057377]]), array([[7.3852459]])]
